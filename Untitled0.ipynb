# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels.formula.api as smf

# %%
datos=pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/peliculas.csv')

# %%
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate  length rating  \
# ...

# %%
datos.info()
#Esto nos muestra la cantidad de filas del dataframe lo que indirectamente nos dice cuantas peliculas hay
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             1000 non-null   object
#  1   description       1000 non-null   object
#  2   release_year      1000 non-null   int64
#  3   rental_rate       1000 non-null   float64
#  4   length            1000 non-null   int64
#  5   rating            1000 non-null   object
#  6   special_features  1000 non-null   object
#  7   category          997 non-null    object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 62.6+ KB

# %%
total_categorias=datos.groupby('category').agg('count')
#Agrupamos el dataframe por categoria (category) para que nos muestre cuantas categorias hay y cuantas peliculas hay por categoria

# %%
total_categorias.sum()
# Out:
# title               997
# description         997
# release_year        997
# rental_rate         997
# length              997
# rating              997
# special_features    997
# dtype: int64

# %% [markdown]
# # Podemos observar que hay 997 peliculas en total, usando la columna "title" como referencia

# %% [markdown]
# # De arriba podemos notar que hay 16 categorias en total

# %%
duracion_promedio=(datos['length'].mean())/60
# Out:
# 1.9212

# %% [markdown]
# # Observamos que la duracion promedio en horas de las peliculas es de 1.9212

# %%
datos['length']=datos['length']/60

# %%
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate    length rating  \
# ...

# %% [markdown]
# # Convertimos la columna length de minutos a horas

# %%
peliculas_dormir=datos.query('category=="Documentary"&length>2')

# %%
peliculas_dormir
# Out:
#                      title                                        description  \
# 39        Army Flintstones  A Boring Saga of a Database Administrator And ...
# 57     Beach Heartbreakers  A Fateful Display of a Womanizer And a Mad Sci...
# 128             Cause Date  A Taut Tale of a Explorer And a Pastry Chef wh...
# 141   Chicken Hellfighters  A Emotional Drama of a Dog And a Explorer who ...
# 155          Clerks Angels  A Thrilling Display of a Sumo Wrestler And a G...
# 205          Dancing Fever  A Stunning Story of a Explorer And a Forensic ...
# 247             Dozen Lion  A Taut Drama of a Cat And a Girl who must Defe...
# 260      Duffel Apocalypse  A Emotional Display of a Boat And a Explorer w...
# 440           Hunter Alter  A Emotional Drama of a Mad Cow And a Boat who ...
# 456     Independence Hotel  A Thrilling Tale of a Technical Writer And a B...
# 543           Madison Trap  A Awe-Inspiring Reflection of a Monkey And a D...
# ...

# %%
total_categorias
#Agrupamos el dataframe por categoria (category) para que nos muestre cuantas categorias hay y cuantas peliculas hay por categoria
# Out:
#              title  description  release_year  rental_rate  length  rating  \
# category
# Action          64           64            64           64      64      64
# Animation       66           66            66           66      66      66
# Children        60           60            60           60      60      60
# Classics        57           57            57           57      57      57
# Comedy          58           58            58           58      58      58
# Documentary     68           68            68           68      68      68
# Drama           61           61            61           61      61      61
# Family          69           69            69           69      69      69
# Foreign         73           73            73           73      73      73
# Games           61           61            61           61      61      61
# Horror          56           56            56           56      56      56
# ...

# %%
datos.groupby('category')['length'].agg('mean')
# Out:
# category
# Action         1.860156
# Animation      1.850253
# Children       1.830000
# Classics       1.861111
# Comedy         1.930460
# Documentary    1.812500
# Drama          1.998087
# Family         1.913043
# Foreign        2.028311
# Games          2.130601
# Horror         1.874702
# Music          1.894118
# New            1.852116
# Sci-Fi         1.803279
# Sports         2.125114
# Travel         1.889583
# Name: length, dtype: float64

# %%
datos['Tiempo']=np.where(datos['length']<1.5,'Corta',np.where(datos['length']>=2.5,'Larga','Normal'))

# %%
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate    length rating  \
# ...

# %%
orden=total_categorias.sort_values('title',ascending=False)

# %%
orden
# Out:
#              title  description  release_year  rental_rate  length  rating  \
# category
# Foreign         73           73            73           73      73      73
# Sports          73           73            73           73      73      73
# Family          69           69            69           69      69      69
# Documentary     68           68            68           68      68      68
# Animation       66           66            66           66      66      66
# Action          64           64            64           64      64      64
# New             63           63            63           63      63      63
# Drama           61           61            61           61      61      61
# Games           61           61            61           61      61      61
# Sci-Fi          61           61            61           61      61      61
# Children        60           60            60           60      60      60
# ...

# %%
orden['title'].plot.bar()
plt.title('Peliculas por genero')
plt.ylabel('Peliculas')
plt.show()
